# %% [markdown]
# # Pokemon ETL Project

# %% [markdown]
# We will go through the ETL (Extract, Transform, Load) process using this notebook

# %% [markdown]
# ### Extract
# We used our 2 sources (https://www.kaggle.com/abcsds/pokemon and https://rapidapi.com/Chewett/api/pokemon-go1?endpoint=apiendpoint_e0cea6ae-58e1-4b27-85ed-756803df433e) to find the names, types and stats from each main series Pokemon and Pokemon GO Pokemons.

# %%
# Invite the homies to the party
import json
import requests
from pprint import pprint
import pandas as pd
from sqlalchemy import create_engine

# %%
# How fast can we turn this into pandas?
df_2= pd.read_csv('Pokemon.csv')
df_2
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
url = "https://pokemon-go1.p.rapidapi.com/pokemon_types.json"

headers = {
    'x-rapidapi-key': "2ec65538b3mshb9a91e32d22edebp169cc0jsn469a94b4a3b1",
    'x-rapidapi-host': "pokemon-go1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# [
#     {
#         "form": "Fall_2019",
#         "pokemon_id": 1,
#         "pokemon_name": "Bulbasaur",
#         "type": [
#             "Grass",
#             "Poison"
#         ]
#     },
#     {
#         "form": "Normal",
#         "pokemon_id": 1,
#         "pokemon_name": "Bulbasaur",
#         "type": [
#             "Grass",
#             "Poison"
#         ]
#     },
#     {
#         "form": "Purified",
#         "pokemon_id": 1,
#         "pokemon_name": "Bulbasaur",
#         "type": [
#             "Grass",
#             "Poison"
#         ]
#     },
#     {
#         "form": "Shadow",
#         "pokemon_id": 1,
#         "pokemon_name": "Bulbasaur",
#         "type": [
#             "Grass",
#             "Poison"
#         ]
#     },
#     {
#         "form": "Normal",
#         "pokemon_id": 2,
#         "pokemon_name": "Ivysaur",
#         "type": [
#             "Grass",
#             "Poison"
#         ]
#     },
#     {
#         "form": "Purified",
# ...

# %%
df = pd.read_json(response.text)
df
# Out:
#            form  pokemon_id pokemon_name             type
# 0     Fall_2019           1    Bulbasaur  [Grass, Poison]
# 1        Normal           1    Bulbasaur  [Grass, Poison]
# 2      Purified           1    Bulbasaur  [Grass, Poison]
# 3        Shadow           1    Bulbasaur  [Grass, Poison]
# 4        Normal           2      Ivysaur  [Grass, Poison]
# ...         ...         ...          ...              ...
# 1278   Purified         866     Mr. Rime   [Ice, Psychic]
# 1279     Shadow         866     Mr. Rime   [Ice, Psychic]
# 1280   Galarian         867    Runerigus  [Ground, Ghost]
# 1281   Purified         867    Runerigus  [Ground, Ghost]
# 1282     Shadow         867    Runerigus  [Ground, Ghost]
#
# [1283 rows x 4 columns]

# %%
url = "https://pokemon-go1.p.rapidapi.com/pokemon_stats.json"

headers = {
    'x-rapidapi-key': "2ec65538b3mshb9a91e32d22edebp169cc0jsn469a94b4a3b1",
    'x-rapidapi-host': "pokemon-go1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# [
#     {
#         "base_attack": 118,
#         "base_defense": 111,
#         "base_stamina": 128,
#         "form": "Fall_2019",
#         "pokemon_id": 1,
#         "pokemon_name": "Bulbasaur"
#     },
#     {
#         "base_attack": 118,
#         "base_defense": 111,
#         "base_stamina": 128,
#         "form": "Normal",
#         "pokemon_id": 1,
#         "pokemon_name": "Bulbasaur"
#     },
#     {
#         "base_attack": 118,
#         "base_defense": 111,
#         "base_stamina": 128,
#         "form": "Purified",
#         "pokemon_id": 1,
#         "pokemon_name": "Bulbasaur"
#     },
#     {
#         "base_attack": 118,
#         "base_defense": 111,
#         "base_stamina": 128,
#         "form": "Shadow",
#         "pokemon_id": 1,
#         "pokemon_name": "Bulbasaur"
#     },
#     {
#         "base_attack": 151,
#         "base_defense": 143,
#         "base_stamina": 155,
#         "form": "Normal",
#         "pokemon_id": 2,
# ...

# %%
df_3 = pd.read_json(response.text)
df_3
# Out:
#       base_attack  base_defense  base_stamina       form  pokemon_id  \
# 0             118           111           128  Fall_2019           1
# 1             118           111           128     Normal           1
# 2             118           111           128   Purified           1
# 3             118           111           128     Shadow           1
# 4             151           143           155     Normal           2
# ...           ...           ...           ...        ...         ...
# 1278          212           179           190   Purified         866
# 1279          212           179           190     Shadow         866
# 1280          163           237           151   Galarian         867
# 1281          163           237           151   Purified         867
# 1282          163           237           151     Shadow         867
#
#      pokemon_name
# 0       Bulbasaur
# 1       Bulbasaur
# 2       Bulbasaur
# 3       Bulbasaur
# 4         Ivysaur
# ...           ...
# ...

# %% [markdown]
# ### Transform
# We used Pandas and Python in order to clean up our data. For our csv, we did the following:
# 1. Use groupby function in order to get the types of pokemons.
# 2. Added a None category for Pokemons without a secondary type.
# 3. Rename our column names so that the would match the tables in our database.
# 4. Rename the index to type_id.
#
# For our JSON files, we did the following:
# 1. Drop columns that we didn't need.
# 2. Drop all types of forms, except Normal.
# 3. Create a function to split the column types into types and sub-types.
# 4. Create a function that checks if new types have been added.
# 5. Merge tables.
# 6. Drop multiple copies of Arceus from final table.
# 7. Check if there is new data by comparing 2 Dataframes.

# %%
# Groupby main type
df_2 = df_2.groupby('Type 1').mean()
df_2
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# ...

# %%
df_2 =  df_2.reset_index()
df_2
# Out:
#       Type 1           #       Total         HP      Attack     Defense  \
# 0        Bug  334.492754  378.927536  56.884058   70.971014   70.724638
# 1       Dark  461.354839  445.741935  66.806452   88.387097   70.225806
# 2     Dragon  474.375000  550.531250  83.312500  112.125000   86.375000
# 3   Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# 4      Fairy  449.529412  413.176471  74.117647   61.529412   65.705882
# 5   Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# 6       Fire  327.403846  458.076923  69.903846   84.769231   67.769231
# 7     Flying  677.750000  485.000000  70.750000   78.750000   66.250000
# 8      Ghost  486.500000  439.562500  64.437500   73.781250   81.187500
# 9      Grass  344.871429  421.142857  67.271429   73.214286   70.800000
# 10    Ground  356.281250  437.500000  73.781250   95.750000   84.843750
# 11       Ice  423.541667  433.458333  72.000000   72.750000   71.416667
# ...

# %%
# Add 'None' type for pokemon without a sub-type
df_2 = df_2[['Type 1']]
df_2
# Out:
#       Type 1
# 0        Bug
# 1       Dark
# 2     Dragon
# 3   Electric
# 4      Fairy
# 5   Fighting
# 6       Fire
# 7     Flying
# 8      Ghost
# 9      Grass
# 10    Ground
# 11       Ice
# 12    Normal
# 13    Poison
# 14   Psychic
# 15      Rock
# 16     Steel
# 17     Water

# %%
# Rename column so they match pgAdmin table
df_2 = df_2.rename(columns={"Type 1": "types"})
df_2.head()
# Out:
#       types
# 0       Bug
# 1      Dark
# 2    Dragon
# 3  Electric
# 4     Fairy

# %%
# Rename index
df_2.index.name = 'type_id'
df_2 = df_2.reset_index()

# %%
df_2.head()
# Out:
#    type_id     types
# 0        0       Bug
# 1        1      Dark
# 2        2    Dragon
# 3        3  Electric
# 4        4     Fairy

# %%
# Drop duplicates and unnecesarry columns
df_3 = df_3.drop_duplicates(subset="pokemon_name")
df_3 = df_3[["base_attack", "base_defense", "base_stamina", "pokemon_id"]]
df_3
# Out:
#       base_attack  base_defense  base_stamina  pokemon_id
# 0             118           111           128           1
# 4             151           143           155           2
# 7             198           189           190           3
# 11            116            93           118           4
# 15            158           126           151           5
# ...           ...           ...           ...         ...
# 1268          180           194           212         862
# 1271          195           162           172         863
# 1274          248           176           158         865
# 1277          212           179           190         866
# 1280          163           237           151         867
#
# [725 rows x 4 columns]

# %%
# Drop all forms except 'Normal'
types = df_2['types'].values
df['check'] = df['form'].isin(types)
df.head()
# Out:
#         form  pokemon_id pokemon_name             type  check
# 0  Fall_2019           1    Bulbasaur  [Grass, Poison]  False
# 1     Normal           1    Bulbasaur  [Grass, Poison]   True
# 2   Purified           1    Bulbasaur  [Grass, Poison]  False
# 3     Shadow           1    Bulbasaur  [Grass, Poison]  False
# 4     Normal           2      Ivysaur  [Grass, Poison]   True

# %%
df = df.loc[df['check'] == True]
df.head()
# Out:
#       form  pokemon_id pokemon_name             type  check
# 1   Normal           1    Bulbasaur  [Grass, Poison]   True
# 4   Normal           2      Ivysaur  [Grass, Poison]   True
# 8   Normal           3     Venusaur  [Grass, Poison]   True
# 12  Normal           4   Charmander           [Fire]   True
# 15  Normal           5   Charmeleon           [Fire]   True

# %%
df = df.drop(columns=['check'])
df.head()
# Out:
#       form  pokemon_id pokemon_name             type
# 1   Normal           1    Bulbasaur  [Grass, Poison]
# 4   Normal           2      Ivysaur  [Grass, Poison]
# 8   Normal           3     Venusaur  [Grass, Poison]
# 12  Normal           4   Charmander           [Fire]
# 15  Normal           5   Charmeleon           [Fire]

# %%
df = df.reset_index()
df.head()
# Out:
#    index    form  pokemon_id pokemon_name             type
# 0      1  Normal           1    Bulbasaur  [Grass, Poison]
# 1      4  Normal           2      Ivysaur  [Grass, Poison]
# 2      8  Normal           3     Venusaur  [Grass, Poison]
# 3     12  Normal           4   Charmander           [Fire]
# 4     15  Normal           5   Charmeleon           [Fire]

# %%
# Create function to split 'type' column into 'type' and 'sub-type'
def sub_type_formula(x):
    if len(x) > 1:
        return x[1]
    else:
        return 'None'
    
def type_formula(x):
    return x[0]

df['sub-type'] = df.apply(lambda row: sub_type_formula(row['type']), axis=1)
df['type'] = df.apply(lambda row: type_formula(row['type']), axis=1)
df
# Out:
#      index    form  pokemon_id pokemon_name    type sub-type
# 0        1  Normal           1    Bulbasaur   Grass   Poison
# 1        4  Normal           2      Ivysaur   Grass   Poison
# 2        8  Normal           3     Venusaur   Grass   Poison
# 3       12  Normal           4   Charmander    Fire     None
# 4       15  Normal           5   Charmeleon    Fire     None
# ..     ...     ...         ...          ...     ...      ...
# 716   1263  Normal         716      Xerneas   Fairy     None
# 717   1264  Normal         717      Yveltal    Dark   Flying
# 718   1265  Normal         718      Zygarde  Dragon   Ground
# 719   1266  Normal         808       Meltan   Steel     None
# 720   1267  Normal         809     Melmetal   Steel     None
#
# [721 rows x 6 columns]

# %%
# Check for new types of Pokemon
current_types = df_2['types'].tolist()
all_types = df['type'].tolist()
all_sub_types = df['sub-type'].tolist()

for poke_type in all_types:
    if poke_type not in all_types:
        pikachu = {"type_id": len(current_types), "types": [poke_type]}
        temp_df = pd.DataFrame(data=pikachu)
        df_2 = df_2.append(temp_df, ignore_index=True)
        all_types.append(poke_type)

for poke_type in all_sub_types:
    if poke_type not in all_types:
        pikachu = {"type_id": len(current_types), "types": [poke_type]}
        temp_df = pd.DataFrame(data=pikachu)
        df_2 = df_2.append(temp_df, ignore_index=True)
        all_types.append(poke_type)
        
df_2
# Out:
#     type_id     types
# 0         0       Bug
# 1         1      Dark
# 2         2    Dragon
# 3         3  Electric
# 4         4     Fairy
# 5         5  Fighting
# 6         6      Fire
# 7         7    Flying
# 8         8     Ghost
# 9         9     Grass
# 10       10    Ground
# 11       11       Ice
# 12       12    Normal
# 13       13    Poison
# 14       14   Psychic
# 15       15      Rock
# 16       16     Steel
# 17       17     Water
# 18       18      None

# %%
# Merge to add pokemon_type_id
df = df.merge(df_2, left_on="type", right_on="types")
df = df.rename(columns={"type_id": "pokemon_type_id"})
df
# Out:
#      index    form  pokemon_id pokemon_name    type sub-type  pokemon_type_id  \
# 0        1  Normal           1    Bulbasaur   Grass   Poison                9
# 1        4  Normal           2      Ivysaur   Grass   Poison                9
# 2        8  Normal           3     Venusaur   Grass   Poison                9
# 3      117  Normal          43       Oddish   Grass   Poison                9
# 4      120  Normal          44        Gloom   Grass   Poison                9
# ..     ...     ...         ...          ...     ...      ...              ...
# 716   1266  Normal         808       Meltan   Steel     None               16
# 717   1267  Normal         809     Melmetal   Steel     None               16
# 718    993  Flying         493       Arceus  Flying     None                7
# 719   1261  Normal         714       Noibat  Flying   Dragon                7
# 720   1262  Normal         715      Noivern  Flying   Dragon                7
#
#       types
# 0     Grass
# ...

# %%
# Adding subtype id
df = df.merge(df_2, how="left", left_on="sub-type", right_on="types")
df = df.rename(columns={"type_id": "pokemon_sub-type_id"})
df
# Out:
#      index    form  pokemon_id pokemon_name    type sub-type  pokemon_type_id  \
# 0        1  Normal           1    Bulbasaur   Grass   Poison                9
# 1        4  Normal           2      Ivysaur   Grass   Poison                9
# 2        8  Normal           3     Venusaur   Grass   Poison                9
# 3      117  Normal          43       Oddish   Grass   Poison                9
# 4      120  Normal          44        Gloom   Grass   Poison                9
# ..     ...     ...         ...          ...     ...      ...              ...
# 716   1266  Normal         808       Meltan   Steel     None               16
# 717   1267  Normal         809     Melmetal   Steel     None               16
# 718    993  Flying         493       Arceus  Flying     None                7
# 719   1261  Normal         714       Noibat  Flying   Dragon                7
# 720   1262  Normal         715      Noivern  Flying   Dragon                7
#
# ...

# %%
# Merge to add stats
df = df.merge(df_3, how="left", left_on="pokemon_id", right_on="pokemon_id")
df
# Out:
#      index    form  pokemon_id pokemon_name    type sub-type  pokemon_type_id  \
# 0        1  Normal           1    Bulbasaur   Grass   Poison                9
# 1        4  Normal           2      Ivysaur   Grass   Poison                9
# 2        8  Normal           3     Venusaur   Grass   Poison                9
# 3      117  Normal          43       Oddish   Grass   Poison                9
# 4      120  Normal          44        Gloom   Grass   Poison                9
# ..     ...     ...         ...          ...     ...      ...              ...
# 716   1266  Normal         808       Meltan   Steel     None               16
# 717   1267  Normal         809     Melmetal   Steel     None               16
# 718    993  Flying         493       Arceus  Flying     None                7
# 719   1261  Normal         714       Noibat  Flying   Dragon                7
# 720   1262  Normal         715      Noivern  Flying   Dragon                7
#
# ...

# %%
# Include columns needed for pgAdmin
column_names = ["pokemon_id", "pokemon_type_id", "pokemon_sub-type_id", "pokemon_name", 
                "base_attack", "base_defense", "base_stamina"]
df = df[column_names]
df
# Out:
#      pokemon_id  pokemon_type_id  pokemon_sub-type_id pokemon_name  \
# 0             1                9                   13    Bulbasaur
# 1             2                9                   13      Ivysaur
# 2             3                9                   13     Venusaur
# 3            43                9                   13       Oddish
# 4            44                9                   13        Gloom
# ..          ...              ...                  ...          ...
# 716         808               16                   18       Meltan
# 717         809               16                   18     Melmetal
# 718         493                7                   18       Arceus
# 719         714                7                    2       Noibat
# 720         715                7                    2      Noivern
#
#      base_attack  base_defense  base_stamina
# 0            118           111           128
# 1            151           143           155
# ...

# %%
# Drop many instances of Arceus
df.drop(df.loc[(df.pokemon_name == 'Arceus') & (df.pokemon_type_id != 12 )].index, inplace=True)
df
# Out:
# C:\Users\JORMIL\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#      pokemon_id  pokemon_type_id  pokemon_sub-type_id pokemon_name  \
# 0             1                9                   13    Bulbasaur
# 1             2                9                   13      Ivysaur
# 2             3                9                   13     Venusaur
# 3            43                9                   13       Oddish
# 4            44                9                   13        Gloom
# ..          ...              ...                  ...          ...
# 715         707               16                    4       Klefki
# 716         808               16                   18       Meltan
# ...

# %% [markdown]
# ### Load

# %% [markdown]
# #### Create database connection

# %%
engine = create_engine('postgresql://postgres:postgres@localhost:5432/Pokemon_DB')
connection = engine.connect()

# %%
# Confirm tables
engine.table_names()
# Out:
# ['types', 'pokemon']

# %% [markdown]
# #### Finding if there is new data to append

# %%
current_types = pd.read_sql_query('select * from "types"',con=engine)
current_types
# Out:
#     type_id     types
# 0         0       Bug
# 1         1      Dark
# 2         2    Dragon
# 3         3  Electric
# 4         4     Fairy
# 5         5  Fighting
# 6         6      Fire
# 7         7    Flying
# 8         8     Ghost
# 9         9     Grass
# 10       10    Ground
# 11       11       Ice
# 12       12    Normal
# 13       13    Poison
# 14       14   Psychic
# 15       15      Rock
# 16       16     Steel
# 17       17     Water
# 18       18      None

# %%
new_types = pd.concat([current_types, df_2]).loc[current_types.index.symmetric_difference(df_2.index)]
new_types
# Out:
# Empty DataFrame
# Columns: [type_id, types]
# Index: []

# %%
current_pokemon = pd.read_sql_query('select * from "pokemon"',con=engine)
current_pokemon
# Out:
#      pokemon_id  pokemon_type_id  pokemon_sub-type_id pokemon_name  \
# 0             1                9                   13    Bulbasaur
# 1             2                9                   13      Ivysaur
# 2             3                9                   13     Venusaur
# 3            43                9                   13       Oddish
# 4            44                9                   13        Gloom
# ..          ...              ...                  ...          ...
# 699         707               16                    4       Klefki
# 700         808               16                   18       Meltan
# 701         809               16                   18     Melmetal
# 702         714                7                    2       Noibat
# 703         715                7                    2      Noivern
#
#      base_attack  base_defense  base_stamina
# 0            118           111           128
# 1            151           143           155
# ...

# %%
df = df.reset_index()
new_pokemon = pd.concat([current_pokemon, df]).loc[current_pokemon.index.symmetric_difference(df.index)]
new_pokemon = new_pokemon.drop(columns=['index'])
new_pokemon
# Out:
# Empty DataFrame
# Columns: [pokemon_id, pokemon_type_id, pokemon_sub-type_id, pokemon_name, base_attack, base_defense, base_stamina]
# Index: []

# %% [markdown]
# #### Load DataFrames into database

# %%
new_types.to_sql(name='types', con=engine, if_exists='append', index=False)

# %%
new_pokemon.to_sql(name='pokemon', con=engine, if_exists='append', index=False)

# %% [markdown]
# #### Confirm data has been added by querying the tables
# * NOTE: can also check using pgAdmin

# %%
pd.read_sql_query('select * from types', con=engine)
# Out:
#     type_id     types
# 0         0       Bug
# 1         1      Dark
# 2         2    Dragon
# 3         3  Electric
# 4         4     Fairy
# 5         5  Fighting
# 6         6      Fire
# 7         7    Flying
# 8         8     Ghost
# 9         9     Grass
# 10       10    Ground
# 11       11       Ice
# 12       12    Normal
# 13       13    Poison
# 14       14   Psychic
# 15       15      Rock
# 16       16     Steel
# 17       17     Water
# 18       18      None

# %%
pd.read_sql_query('select * from pokemon', con=engine)
# Out:
#      pokemon_id  pokemon_type_id  pokemon_sub-type_id pokemon_name  \
# 0             1                9                   13    Bulbasaur
# 1             2                9                   13      Ivysaur
# 2             3                9                   13     Venusaur
# 3            43                9                   13       Oddish
# 4            44                9                   13        Gloom
# ..          ...              ...                  ...          ...
# 699         707               16                    4       Klefki
# 700         808               16                   18       Meltan
# 701         809               16                   18     Melmetal
# 702         714                7                    2       Noibat
# 703         715                7                    2      Noivern
#
#      base_attack  base_defense  base_stamina
# 0            118           111           128
# 1            151           143           155
# ...
